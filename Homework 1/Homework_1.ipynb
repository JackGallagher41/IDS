# %% [markdown]
# <a href="https://colab.research.google.com/github/JackGallagher41/IDS/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Problem 1:**

# %% [markdown]
# ![Sum total table HW1 Database.png](data:image/png;base64,...)![Feed min mean max data science HW1.png](data:image/png;base64,...)

# %% [markdown]
# Based on the chicken feed data, which type of chicken food appears the most beneﬁcial for a thriving poultry business? Explain your answer.
#
# When looking over the data collected it is safe to assume sunflower is the best option. Sunflower held the highest max, highest min, highest average and highest sum. When looking at the data though it can be argued highest average is the most important statistic. This is due to min and a max be outliars, as well as total sum being scewed due to having uneven amounts of tests per chicken feed.

# %% [markdown]
# Excel Link: https://sju-my.sharepoint.com/:x:/r/personal/jg749036_sju_edu/_layouts/15/Doc.aspx?sourcedoc=%7B4B2A3743-1363-41B0-900F-25D2C1369C95%7D&file=chickwts.xlsx&action=default&mobileredirect=true&DefaultItemOpen=1&login_hint=jg749036%40sju.edu&ct=1694055542715&wdOrigin=OFFICECOM-WEB.START.EDGEWORTH&cid=98027640-27f7-4213-b5a9-a81dc0d89d1f&wdPreviousSessionSrc=HarmonyWeb&wdPreviousSession=7dff10f0-3434-4dc3-89ab-a5e1a6fd27ef

# %% [markdown]
# #**Problem 2:**

# %% [markdown]
# ![Insurance Sum Better HW1 Datascience.png](data:image/png;base64,...)![Insurance Table HW1 Datascience.png](data:image/png;base64,...)

# %% [markdown]
# Perform similar analyses as you did in Problem 1 and determine if you had to choose an auto insurance provider based on these ratings, which one you would opt for. Explain your answer.
#
# When analyzing the data it is safe to assume that progressive is the favorite. This can be determined through the holding the highest average or the highest sum due to the same number of tests. It is also reassuring that they have the highest minimum as well.

# %% [markdown]
# Excel Link: https://sju-my.sharepoint.com/:x:/r/personal/jg749036_sju_edu/_layouts/15/Doc.aspx?sourcedoc=%7B765FFB31-CCFF-4614-BA1A-32887E517F93%7D&file=Book%201%20-%20Copy.xlsx&action=default&mobileredirect=true&DefaultItemOpen=1&ct=1694057502843&wdOrigin=OFFICECOM-HWA.START.EDGEWORTH&cid=e690da85-aea4-4b18-af7e-faa57d840472&wdPreviousSessionSrc=HarmonyDesktop&wdPreviousSession=188714f2-d144-492e-bbb7-b02176f4e9af
