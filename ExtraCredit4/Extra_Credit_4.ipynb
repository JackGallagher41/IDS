# %% [markdown]
# <a href="https://colab.research.google.com/github/JackGallagher41/IDS/blob/Data-Science-extra-credit/Extra_Credit_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Jack Gallagher**

# %% [markdown]
# ### Output Majors and the count of students in each major. Sort by count of major from most to least.

# %% [markdown]
# ![Extra credit 4 Major Count.png](data:image/png;base64,...)
