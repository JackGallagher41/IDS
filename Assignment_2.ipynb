# %% [markdown]
# <a href="https://colab.research.google.com/github/JackGallagher41/IDS/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Jack Gallagher**

# %% [markdown]
# ##**Problem 1.)** The dataset USArrests.csv contains statistics in arrests per 100,000 residents for assault and murder, in each of the 50 US states, in 1973. Also given is the percentage of the population living in urban areas:

# %% [markdown]
# ## **Excel**

# %% [markdown]
# ***A. Address all the missing values***
#
# Selected all blank cells and filled them with the column averages

# %% [markdown]
# ***B.Look for outliers and smooth noisy data, if any***
#
# Checked for negatives and used IQR to search for any outliers. (nothing needed to be changed)

# %% [markdown]
# ***C. Plot Murder rates for all 50 states***

# %% [markdown]
# ![Murder rate 50 states.png](data:image/png;base64,...)

# %% [markdown]
# ***D. Plot histogram of assaults***

# %% [markdown]
# ![Assault Histogram.png](data:image/png;base64,...)

# %% [markdown]
# ***E. Plot Murder rate vs. Assault rate***

# %% [markdown]
# ![Murder Vs Assault chart.png](data:image/png;base64,...)

# %% [markdown]
# ***F. Prepare the dataset to establish a relation between an urban population category and a crime type. Hint: Convert the urban population percentage into categories, for example, small (<50%), medium (<60%), large (<70%), and extra-large (70% and above) urban population***

# %% [markdown]
# ![UrbanPop Arrest.png](data:image/png;base64,...)

# %% [markdown]
# ![Murder urbanpop.png](data:image/png;base64,...)

# %% [markdown]
# The Data shows there to not be much of a correlation between urban population and the specific crime types.

# %% [markdown]
# ## **SQL**

# %% [markdown]
# ***A. Import the original CSV file into SQL and create the table USArrests.
# Hint: Use the CSV to SQL Convertor: https://www.convertcsv.com/csv-to-sql.htmLinks to an external site.***

# %% [markdown]
# ***B. Use SQL (https://www.programiz.com/sql/online-compiler/Links to an external site.) to replace all missing values in a column by the average***

# %% [markdown]
# ![USArrests fill in table.png](data:image/png;base64,...)

# %% [markdown]
# ***C. Find min, max, mean, and variance of all numeric attributes in SQL.***

# %% [markdown]
# ![SQL stuff.png](data:image/png;base64,...)![SQL Stuff 2.png](data:image/png;base64,...)

# %% [markdown]
# ***D. Use SQL to answer the following questions:
# -- Which state has the maximum murder rate?
# -- List of states in ascending order of urban population percentages.
# -- How many states have higher murder rates than Arizona? List those states***

# %% [markdown]
# ![Fun code.png](data:image/png;base64,...)

# %% [markdown]
# ##**Problem 2.)** This problem's dataset involves child mortality rates and is inspired by data collected from UNICEF. The original dataset is available here: https://github.com/bforoura/IDS/tree/main/HW2Links to an external site.
#
# ##According to the report, the world has achieved substantial success in reducing child mortality during the last few decades. According to the UNICEF report, globally the under-ﬁve age mortality rate has decreased from 93 deaths per 1,000 live births in 1990 to less than 50 in 2016.
#
# ##However, the dataset has a number of missing instances, which need to be fixed before a clear progress on child mortality can be explained from the year of 1990 to 2016. Use this dataset to complete the following tasks:

# %% [markdown]
# ## **Excel**

# %% [markdown]
# ***A. Address all the missing values using the techniques at your disposal.***

# %% [markdown]
# Replaced the empty values with average. I noticed that is a consitant descent but wasn't sure if i could get targeted averages of where they are in the table or not assuming it could be a table of huge values. I feel the argument for removing the rows could be a strong perspective as well.

# %% [markdown]
# ***B. Prepare the dataset to establish the following relations (graphs in Excel):
# --Under-ﬁve mortality rate and neonatal mortality rate.
# --Infant mortality rate and neonatal mortality rate.
# --Year and infant mortality rate***

# %% [markdown]
# ![Neo and Underfive real.png](data:image/png;base64,...)

# %% [markdown]
# ![Neo and Infant real.png](data:image/png;base64,...)

# %% [markdown]
# ![Infant Likert Scale.png](data:image/png;base64,...)

# %% [markdown]
# All mortality levels when compared to eachother as well as when compared to the years show a consistant drop over time. We are also able to pull from the information that under-five consitantly holds the most followed by infant and then by neo.

# %% [markdown]
# ## **SQL**

# %% [markdown]
# ***A. Import the original data set into SQL (see problem 1).***

# %% [markdown]
# ***B. Use SQL to fill in the missing values in each column using the medians.***

# %% [markdown]
# ![median updates.png](data:image/png;base64,...)

# %% [markdown]
# ***Answer the following queries in SQL:
# -- Display the entire table.
# -- Which years have the lowest and highest infant mortality years, respectively?
# -- In what years the neonatal mortality rates were above average?
# -- Display the sorted infant mortality rates in descending order.
# -- Display min, max, mean, variance, and standard deviation for each mortality rate.
# -- Add a new column called Above-Five Mortality Rate and populate it with appropriate values. Hint: Use Alter Table Add Column.
# -- Display the entire table again.***

# %% [markdown]
# ![Printing 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Printing 2.png](data:image/png;base64,...)

# %% [markdown]
# ![printing 3.png](data:image/png;base64,...)

# %% [markdown]
# ![print 4.png](data:image/png;base64,...)

# %% [markdown]
# ![print 5.png](data:image/png;base64,...)

# %% [markdown]
# ![print 6.png](data:image/png;base64,...)

# %% [markdown]
# ![final print.png](data:image/png;base64,...)

# %% [markdown]
# ![final print.png](data:image/png;base64,...)
