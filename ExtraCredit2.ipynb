# %% [markdown]
# <a href="https://colab.research.google.com/github/JackGallagher41/IDS/blob/Data-Science-extra-credit/ExtraCredit2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##First I created the table with the code given (had to adjust due to enum not being supported):

# %% [markdown]
# ![Extra credit 2 full table.png](data:image/png;base64,...)

# %% [markdown]
# ##I then followed it up calling up certain data using SQL lines that we went over in class:

# %% [markdown]
# ![Extra credit 2 sql code datascience.png](data:image/png;base64,...)

# %% [markdown]
# ![Extra credit 2 found tables 1 datascience.png](data:image/png;base64,...)

# %% [markdown]
# ![Extra credit 2 found tables 2 datascience.png](data:image/png;base64,...)
